# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp

T = 80
alpha = 0.3
beta = 2.0
pra = 0.7
prb = 0.3

ra = tfp.distributions.Bernoulli(probs=pra, dtype=tf.float32)
rb = tfp.distributions.Bernoulli(probs=prb, dtype=tf.float32)
Q = np.zeros((2, T+1), dtype=np.float32)
choices = np.zeros((T, ), dtype=np.int32)
rewards = np.zeros((T, ), dtype=np.float32)
pahist = np.zeros((T+1, ), dtype=np.float32)

for t in range(1, T):
    pa = 1. / (1 + tf.exp(-beta * (Q[0, t] - Q[1, t])))
    pahist[t+1] = pa
    a = tfp.distributions.Bernoulli(probs=pa, dtype=tf.bool).sample(1)[0]
    choices[t] = a
    if a == True:
        r = ra.sample(1)[0]
        Q[0, t+1] = Q[0, t] + alpha * (r - Q[0, t]) 
        Q[1, t+1] = Q[1, t]
    else:
        r = rb.sample(1)[0]
        Q[1, t+1] = Q[1, t] + alpha * (r - Q[1, t]) 
        Q[0, t+1] = Q[0, t]
    rewards[t] = r
# Out:
# 2021-08-18 23:21:35.845554: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-08-18 23:21:35.853175: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-08-18 23:21:37.770080: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-08-18 23:21:37.770123: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-08-18 23:21:37.770156: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-26-3-85): /proc/driver/nvidia/version does not exist
# 2021-08-18 23:21:37.770444: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
plt.plot(range(T+1), Q[0, :], label='A')
plt.plot(range(T+1), Q[1, :], label='B')
plt.plot(range(T+1), pahist, label='pa')
plt.legend()
plt.show()

# %%
import functools

T = 80

def make_val_and_grad_fn(value_fn):
    @functools.wraps(value_fn)
    def val_and_grad(x):
        return tfp.math.value_and_gradient(value_fn, x)
    return val_and_grad

@make_val_and_grad_fn
def simulate(params):
    tf.print(params)
    alpha_est, beta_est = tf.exp(params[0]), tf.exp(params[1])
    Qa = np.array(0.0, dtype=np.float32)
    Qb = np.array(0.0, dtype=np.float32)
    ll = tf.Variable(0.0, dtype=np.float32)

    alpha_prior = tfp.distributions.Beta(2.0, 2.0)
    beta_prior = tfp.distributions.Gamma(2.0, 0.3333)

    for t in range(T):
        pa = 1. / (1 + tf.exp(-beta_est * (Qa- Qb)))
        pa = tf.clip_by_value(pa, 0.00001, 0.99999)
        ll = ll + choices[t] * tf.math.log(pa) + (1 - choices[t]) * tf.math.log(1 - pa)

        if choices[t] == 1:
            Qa = Qa + alpha_est * (rewards[t] - Qa)
        else:
            Qb = Qb + alpha_est * (rewards[t] - Qb)
    tf.print(ll)
    return -ll - alpha_prior.log_prob(tf.clip_by_value(alpha_est, 0.00001, 0.99999)) - beta_prior.log_prob(tf.clip_by_value(beta_est, 0.00001, np.finfo(np.float32).max - 0.00001))

alpha_est = 0.
beta_est = 0.

optim_results = tfp.optimizer.lbfgs_minimize(
    simulate, initial_position=np.array([alpha_est, beta_est], dtype=np.float32))
# Out:
# [0 0]
# -47.2172699
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_77891/2166178911.py in <module>
#      35 beta_est = 0.
#      36
# ---> 37 optim_results = tfp.optimizer.lbfgs_minimize(
#      38     simulate, initial_position=np.array([alpha_est, beta_est], dtype=np.float32))
#
# ~/.cache/pypoetry/virtualenvs/behavior-data-computation-modeling-for-pyt-shJiIBXb-py3.9/lib/python3.9/site-packages/tensorflow_probability/python/optimizer/lbfgs.py in minimize(value_and_gradients_function, initial_position, previous_optimizer_results, num_correction_pairs, tolerance, x_tolerance, f_relative_tolerance, initial_inverse_hessian_estimate, max_iterations, parallel_iterations, stopping_condition, max_line_search_iterations, name)
#     275     if previous_optimizer_results is None:
#     276       assert initial_position is not None
# --> 277       initial_state = _get_initial_state(value_and_gradients_function,
#     278                                          initial_position,
#     279                                          num_correction_pairs,
#
# ~/.cache/pypoetry/virtualenvs/behavior-data-computation-modeling-for-pyt-shJiIBXb-py3.9/lib/python3.9/site-packages/tensorflow_probability/python/optimizer/lbfgs.py in _get_initial_state(value_and_gradients_function, initial_position, num_correction_pairs, tolerance)
#     294                        tolerance):
#     295   """Create LBfgsOptimizerResults with initial state of search procedure."""
# --> 296   init_args = bfgs_utils.get_initial_state_args(
#     297       value_and_gradients_function,
#     298       initial_position,
#
# ~/.cache/pypoetry/virtualenvs/behavior-data-computation-modeling-for-pyt-shJiIBXb-py3.9/lib/python3.9/site-packages/tensorflow_probability/python/optimizer/bfgs_utils.py in get_initial_state_args(value_and_gradients_function, initial_position, grad_tolerance, control_inputs)
#      79       f0, df0 = value_and_gradients_function(initial_position)
#      80   else:
# ---> 81     f0, df0 = value_and_gradients_function(initial_position)
#      82   # This is a gradient-based convergence check.  We only do it for finite
#      83   # objective values because we assume the gradient reported at a position with
#
# /tmp/ipykernel_77891/2166178911.py in val_and_grad(x)
#       6     @functools.wraps(value_fn)
#       7     def val_and_grad(x):
# ----> 8         return tfp.math.value_and_gradient(value_fn, x)
#       9     return val_and_grad
#      10
#
# ~/.cache/pypoetry/virtualenvs/behavior-data-computation-modeling-for-pyt-shJiIBXb-py3.9/lib/python3.9/site-packages/tensorflow_probability/python/math/gradient.py in value_and_gradient(f, output_gradients, use_gradient_tape, auto_unpack_single_arg, name, *args, **kwargs)
#     102   """
#     103   with tf.name_scope(name or 'value_and_gradient'):
# --> 104     return _value_and_grad_impl(
#     105         f,
#     106         _gradient_new if tf.executing_eagerly() or use_gradient_tape else
#
# ~/.cache/pypoetry/virtualenvs/behavior-data-computation-modeling-for-pyt-shJiIBXb-py3.9/lib/python3.9/site-packages/tensorflow_probability/python/math/gradient.py in _value_and_grad_impl(f, grad_fn, output_gradients, auto_unpack_single_arg, expand_tf_modules_as_trainable_vars, *args, **kwargs)
#     330   else:
#     331     expand_args, expand_kwargs = args, kwargs
# --> 332   y, dydx = grad_fn(lambda: f(*args, **kwargs) if _has_args(f) else f(),
#     333                     tf.nest.flatten([expand_args, expand_kwargs]),
#     334                     output_gradients)
#
# ~/.cache/pypoetry/virtualenvs/behavior-data-computation-modeling-for-pyt-shJiIBXb-py3.9/lib/python3.9/site-packages/tensorflow_probability/python/math/gradient.py in _gradient_new(f, xs, grad_ys)
#     283     for x in xs:
#     284       tape.watch(x)
# --> 285     y = f()
#     286   return y, tape.gradient(y, xs, output_gradients=grad_ys)
#     287
#
# ~/.cache/pypoetry/virtualenvs/behavior-data-computation-modeling-for-pyt-shJiIBXb-py3.9/lib/python3.9/site-packages/tensorflow_probability/python/math/gradient.py in <lambda>()
#     330   else:
#     331     expand_args, expand_kwargs = args, kwargs
# --> 332   y, dydx = grad_fn(lambda: f(*args, **kwargs) if _has_args(f) else f(),
#     333                     tf.nest.flatten([expand_args, expand_kwargs]),
#     334                     output_gradients)
#
# /tmp/ipykernel_77891/2166178911.py in simulate(params)
#      30             Qb = Qb + alpha_est * (rewards[t] - Qb)
#      31     tf.print(ll)
# ---> 32     return -ll - alpha_prior.log_prob(tf.clip_by_value(alpha_est, 0.00001, 0.99999)) - beta_prior.log_prob(tf.clip_by_value(beta_est, 0.00001, np.iinfo(np.float32).max - 0.00001))
#      33
#      34 alpha_est = 0.
#
# ~/.cache/pypoetry/virtualenvs/behavior-data-computation-modeling-for-pyt-shJiIBXb-py3.9/lib/python3.9/site-packages/numpy/core/getlimits.py in __init__(self, int_type)
#     505         self.key = "%s%d" % (self.kind, self.bits)
#     506         if self.kind not in 'iu':
# --> 507             raise ValueError("Invalid integer data type %r." % (self.kind,))
#     508
#     509     @property
#
# ValueError: Invalid integer data type 'f'.

# %%
np.exp(optim_results.position.numpy())
# Out:
# array([0.42951652, 1.8518397 ], dtype=float32)
